# %% [markdown]
# # Data Visualisation Statistiques descriptives

# %% [markdown]
# ## Visualisation d’un nuage de points et exploration des variables

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
#print (os.path.abspath(os.path.dirname('house_pricing.csv')))
house = pd.read_csv(os.path.abspath(os.path.dirname('house_pricing.csv'))+"/data/house_pricing.csv",",")

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#plt.figure(figsize=(7,7))
n1 = plt.plot(house.LotArea,house.SalePrice,'.')
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
#plt.figure(figsize=(7,7))
houseReduit = house[(house.LotArea<=20000)&(house.SalePrice<=500000)]
n2 = plt.plot(houseReduit.LotArea,houseReduit.SalePrice,'.')
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
n3 = plt.plot(house.LotFrontage,house.LotArea,'.')
plt.xlabel("LotFrontage")
plt.ylabel("LotArea")
# Out:
# Text(0, 0.5, 'LotArea')

# %%
houseReduit1 = house[(house.LotFrontage<=200)&(house.LotArea<=100000)]
n4 = plt.plot(houseReduit1.LotFrontage,houseReduit1.LotArea,'.')
plt.xlabel("LotFrontage")
plt.ylabel("LotArea")
# Out:
# Text(0, 0.5, 'LotArea')

# %% [markdown]
# ## Visualisation de relations continues

# %%
sales = pd.read_csv(os.path.abspath(os.path.dirname('sales_predictions.csv'))+"/data/sales_predictions.csv",",")
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
n1 = sns.relplot(x='date', y='item_price', data=sales)

# %%
salesReduced = sales.sample(n=50)
salesReduced.head()
salesReduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 322482 to 1214132
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     object
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.7+ KB

# %%
plt.figure(figsize=(20,6))
n1 = sns.relplot(x='date', y='item_price', data=salesReduced,sizes=(20,6))
plt.show()

# %% [markdown]
# On voit que les dates sont mélangées entre elles et on arrive pas a bien distinguer les données par rapport à la date.

# %%
salesReduced.date =(pd.to_datetime(salesReduced.date))

# %%
salesReduced.head()
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 322482  2013-03-23               2       24     7819      8390.0           1.0
# 1651805 2014-05-15              16       12    19321       349.0           1.0
# 327286  2013-03-18               2       27      987       149.0           1.0
# 754696  2013-04-08               7       53    14905       149.0           1.0
# 2534695 2015-01-03              26        6    16493       399.0           1.0

# %%
plt.figure(figsize=(20,6))
n1 = sns.relplot(x='date', y='item_price', data=salesReduced,sizes=(20,6))
plt.show()

# %% [markdown]
# ## Visualisation de variables catégoriques

# %%
#1)
ibm = pd.read_csv(os.path.abspath(os.path.dirname('IBM_HR_ATTRITION.csv'))+"/data/IBM_HR_ATTRITION.csv",",")
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ibm.JobSatisfaction.describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
#2)
sns.set(style="ticks")
l1 = sns.catplot(x='Attrition', y='JobSatisfaction', data=ibm, kind='bar')

# %%
#3)
sns.set(style="whitegrid")
l2 = sns.boxplot(x=ibm['Attrition'], y=ibm['JobSatisfaction'], data=ibm)

# %% [markdown]
# On peut en conclure que les personnes qui ont quittés l'entreprise avaient une satisfaction au travail qui va de 1 à 3.

# %% [markdown]
# 4)
# Oui, le bloxplot permet de voir si une variable présente des valeurs aberrantes.

# %%
#5) ya pas de valeur aberrantes

# %%
#6)
ibm.JobSatisfaction.describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
#7)

# %%
#8)
sns.set(style="whitegrid")
l2 = sns.boxplot(x=ibm['Attrition'], y=ibm['TotalWorkingYears'], data=ibm)

# %% [markdown]
# Plus l'employé est resté dans l'entreprise (nombre d'année travailées élévée), plus il reste dans l'entreprise.

# %%
#9)
ibm.Attrition = ibm['Attrition'].replace('Yes', 1).replace('No', 0)
ibm.Attrition.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Attrition, dtype: int64

# %%
#10)
plt.figure(figsize=(20,8))
plt.hist(ibm.EducationField, bins =10)
# Out:
# (array([606.,   0.,  82.,   0., 464.,   0., 159.,   0., 132.,  27.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Visualisation d’une distribution

# %%
#1-2)
sns.distplot(ibm.MonthlyIncome)

# %%
#3)
dfIbm = ibm[ibm.MonthlyIncome<= 5000]

# %%
sns.distplot(dfIbm.MonthlyIncome)

# %% [markdown]
# ## Visualisation d’une relation linéaire

# %%
#1)
ibm = pd.read_csv(os.path.abspath(os.path.dirname('IBM_HR_ATTRITION.csv'))+"/data/IBM_HR_ATTRITION.csv",",")
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sns.set(style="whitegrid")
sns.lmplot(x='DistanceFromHome', y='Attrition', data=ibm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except ValueError:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-d8bffa17c841> in <module>
# ...

# %%
ibm.Attrition = ibm['Attrition'].replace('Yes', 1).replace('No', 0)
ibm.Attrition.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Attrition, dtype: int64

# %%
sns.set(style="darkgrid")
sns.lmplot(x='DistanceFromHome', y='Attrition', data=ibm)

# %%
sns.set(style="whitegrid")
sns.lmplot(x='YearsWithCurrManager', y='Attrition', data=ibm)

# %% [markdown]
# ## Visualisation d’une heatmap

# %%
os.path.abspath(os.path.dirname('house_pricing.csv'))
# Out:
# 'C:\\Users\\Aliam\\BigDataHadoop\\JAVA-IOT_BigDataHadoop\\Dataviz'

# %%
houseP = pd.read_csv(os.path.abspath(os.path.dirname('house_pricing.csv'))+"/data/house_pricing.csv",",")
houseP.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseShort = houseP.tail(15)
houseShort.describe()
# Out:
#                 Id  MSSubClass  LotFrontage       LotArea  OverallQual  \
# count    15.000000   15.000000    14.000000     15.000000    15.000000
# mean   1453.000000   61.000000    65.857143  10285.600000     5.800000
# std       4.472136   54.582834    18.496807   5682.175926     1.207122
# min    1446.000000   20.000000    21.000000   1533.000000     4.000000
# 25%    1449.500000   20.000000    62.000000   8158.500000     5.000000
# 50%    1453.000000   50.000000    69.000000   9262.000000     5.000000
# 75%    1456.500000   77.500000    77.250000  10883.500000     6.500000
# max    1460.000000  180.000000    90.000000  26142.000000     8.000000
#
#        OverallCond    YearBuilt  YearRemodAdd  MasVnrArea   BsmtFinSF1  ...  \
# count    15.000000    15.000000     15.000000   15.000000    15.000000  ...
# mean      5.866667  1975.533333   1989.866667   68.000000   354.200000  ...
# std       1.187234    28.225790     17.402244  124.327333   361.854193  ...
# ...

# %%
houseShort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 1445 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             15 non-null     int64
#  1   MSSubClass     15 non-null     int64
#  2   MSZoning       15 non-null     object
#  3   LotFrontage    14 non-null     float64
#  4   LotArea        15 non-null     int64
#  5   Street         15 non-null     object
#  6   Alley          1 non-null      object
#  7   LotShape       15 non-null     object
#  8   LandContour    15 non-null     object
#  9   Utilities      15 non-null     object
#  10  LotConfig      15 non-null     object
#  11  LandSlope      15 non-null     object
#  12  Neighborhood   15 non-null     object
#  13  Condition1     15 non-null     object
#  14  Condition2     15 non-null     object
#  15  BldgType       15 non-null     object
#  16  HouseStyle     15 non-null     object
# ...

# %%
corrHouse = houseShort.corr()
corrHouse
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea   OverallQual  \
# Id             1.000000e+00   -0.299933     0.170671 -0.176641  1.175185e-17
# MSSubClass    -2.999333e-01    1.000000    -0.879089 -0.643601 -2.135655e-01
# LotFrontage    1.706710e-01   -0.879089     1.000000  0.914186  2.928409e-01
# LotArea       -1.766413e-01   -0.643601     0.914186  1.000000 -1.544585e-01
# OverallQual    1.175185e-17   -0.213565     0.292841 -0.154458  1.000000e+00
# OverallCond    1.479836e-01    0.051806    -0.176484  0.150015 -1.694586e-01
# YearBuilt      3.847864e-02    0.052251     0.019051 -0.148001  4.729485e-01
# YearRemodAdd   3.193971e-01   -0.124680     0.211581 -0.204825  3.828724e-01
# MasVnrArea    -3.907955e-01   -0.121045     0.279790  0.251578  5.706548e-01
# BsmtFinSF1    -2.039226e-02    0.098483    -0.049288  0.026653  2.180785e-01
# BsmtFinSF2     2.372469e-01   -0.198927     0.142105 -0.058416 -1.765379e-01
# ...

# %%
plt.figure(figsize=(20,9))
sns.heatmap(corrHouse, annot=True)
plt.show()

# %% [markdown]
# 5) Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?
# -LotFrontage
# -OverallQual
# -YearBuild

# %% [markdown]
# ## Formaliser des KPI

# %%
resto = pd.read_csv(os.path.abspath(os.path.dirname('resto.csv'))+"/data/resto.csv",",")
resto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
resto.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
resto.size
# Out:
# 27732

# %%
resto.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
pd.crosstab(resto.item_name, resto.quantity.sum())
# Out:
# col_0                                  4972
# item_name
# 6 Pack Soft Drink                        54
# Barbacoa Bowl                            66
# Barbacoa Burrito                         91
# Barbacoa Crispy Tacos                    11
# Barbacoa Salad Bowl                      10
# Barbacoa Soft Tacos                      25
# Bottled Water                           162
# Bowl                                      2
# Burrito                                   6
# Canned Soda                             104
# Canned Soft Drink                       301
# Carnitas Bowl                            68
# Carnitas Burrito                         59
# Carnitas Crispy Tacos                     7
# Carnitas Salad                            1
# Carnitas Salad Bowl                       6
# Carnitas Soft Tacos                      40
# Chicken Bowl                            726
# Chicken Burrito                         553
# Chicken Crispy Tacos                     47
# ...

# %% [markdown]
# 6) Chicken Bowl	= 726

# %%
resto.item_price = resto.item_price.str[1:-1]
resto.item_price = pd.Series(resto.item_price)

# %%
sum(resto.quantity)
# Out:
# 4972

# %%
# Combien de chiffre d’affaire à realisé Chipotle ?
resto['item_price_int'] = resto['item_price'].str.slice(start=1)
resto['item_price_int'] = pd.to_numeric(resto['item_price_int'])
resto['quantity'] = pd.to_numeric(resto['quantity'])
resto['CA'] = resto['quantity'] * resto['item_price_int']
round(sum(resto['CA']),2)
# Out:
# 39237.02

# %%
# Quel est le revenu moyen par commande ?
resto.CA.describe()
# Out:
# count    4622.000000
# mean        8.489186
# std        12.632060
# min         1.090000
# 25%         3.990000
# 50%         8.750000
# 75%        10.980000
# max       663.750000
# Name: CA, dtype: float64
